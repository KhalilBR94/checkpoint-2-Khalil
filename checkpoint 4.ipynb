# %%
import pandas as pd
data=pd.read_csv(r'C:\Users\ASUS\Downloads\kc_house_data.csv')
data
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics
x=data["price"].values[:,np.newaxis]
y=data["sqft_living"].values

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=40)
model=LinearRegression()   
model.fit(x_train,y_train)  
predicted=model.predict(x_test) 


print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))

plt.scatter(x,y,color="b")
plt.title("Linear Regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(x,model.predict(x),color="k")
plt.show()
# Out:
# MSE 422207.0700380014
# R squared 0.5023802598864712

# %%
data[['price','bedrooms']].corr() 
#faible corrélation
# Out:
#             price  bedrooms
# price     1.00000   0.30835
# bedrooms  0.30835   1.00000

# %%
data[['price','bathrooms']].corr()
# Out:
#               price  bathrooms
# price      1.000000   0.525138
# bathrooms  0.525138   1.000000

# %%
data[['price','sqft_lot']].corr()
# Out:
#              price  sqft_lot
# price     1.000000  0.089661
# sqft_lot  0.089661  1.000000

# %%
data[['price','floors']].corr()
# Out:
#            price    floors
# price   1.000000  0.256794
# floors  0.256794  1.000000

# %%
data[['price','sqft_living']].corr()
# Out:
#                 price  sqft_living
# price        1.000000     0.702035
# sqft_living  0.702035     1.000000

# %%
data[['price','view']].corr()
# Out:
#           price      view
# price  1.000000  0.397293
# view   0.397293  1.000000

# %%
data[['price','waterfront']].corr()
# Out:
#                price  waterfront
# price       1.000000    0.266369
# waterfront  0.266369    1.000000

# %%
data[['price','condition']].corr()
# Out:
#               price  condition
# price      1.000000   0.036362
# condition  0.036362   1.000000

# %%
data[['price','grade']].corr()
# Out:
#           price     grade
# price  1.000000  0.667434
# grade  0.667434  1.000000

# %%
data[['price','sqft_above']].corr()
# Out:
#                price  sqft_above
# price       1.000000    0.605567
# sqft_above  0.605567    1.000000

# %%
data[['price','sqft_basement']].corr()
# Out:
#                   price  sqft_basement
# price          1.000000       0.323816
# sqft_basement  0.323816       1.000000

# %%
data[['price','sqft_basement']].corr()
# Out:
#                   price  sqft_basement
# price          1.000000       0.323816
# sqft_basement  0.323816       1.000000

# %%
x=data["price"].values[:,np.newaxis]
y=data['sqft_above'].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=40)
model=LinearRegression()   
model.fit(x_train,y_train)  
predicted=model.predict(x_test) 


print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))

plt.scatter(x,y,color="b")
plt.title("Linear Regression")
plt.ylabel("price")
plt.xlabel("sqft_above")
plt.plot(x,model.predict(x),color="k")
plt.show()
# Out:
# MSE 434169.08571422804
# R squared 0.3737296413656013

# %%
import seaborn as sns
def plot_correlation_map( data ):
    corr = data.corr()   
    s , ax = plt.subplots( figsize =( 20 , 20 ) )
    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
    s = sns.heatmap(
        corr, 

        cmap = cmap,

        square= True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 10 }   

        )

# %%
plot_correlation_map( data )

# %%
x=data[["sqft_living","grade","sqft_above"]]  
y=data["price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=40) 

model=LinearRegression() 
model.fit(x_train,y_train) 
predicted=model.predict(x_test) 

print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 57370065644.54944
# R squared 0.5537353374086992

# %%
x=data[["sqft_living","grade","sqft_above","sqft_living15","view","bedrooms","sqft_basement","sqft_lot15","long","lat","zipcode","yr_renovated","yr_built","waterfront","floors","sqft_lot","bathrooms","condition"]]  
y=data["price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=40) 

model=LinearRegression() 
model.fit(x_train,y_train) 
predicted=model.predict(x_test) 

print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 38031266997.05991
# R squared 0.7041660952679234

# %%
x=data[["grade","sqft_above","sqft_living15","view","bedrooms","sqft_basement","sqft_lot15","long","lat","zipcode","yr_renovated","yr_built","waterfront","floors","sqft_lot","bathrooms","condition"]]  
y=data["price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=40) 

model=LinearRegression() 
model.fit(x_train,y_train) 
predicted=model.predict(x_test) 

print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 38031266997.05918
# R squared 0.7041660952679292

# %%
#Visualizing the data
import seaborn as sns
sns.pairplot(data, 
             x_vars=["sqft_above", "sqft_living", "grade", "sqft_basement"], 
             y_vars=["price"],
             hue = "bedrooms"
             )

# %%
x=data[["sqft_above"]]  
y=data["price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=40) 

model=LinearRegression() 
model.fit(x_train,y_train) 
predicted=model.predict(x_test) 

print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 80950749591.32977
# R squared 0.3703082165408008

# %%
from sklearn.preprocessing import PolynomialFeatures 
x= data["sqft_living"].values.reshape(-1,1)
y= data["price"].values
poly = PolynomialFeatures(degree = 3) 
x_poly = poly.fit_transform(x) 
poly.fit(x_poly, y) 
lg=LinearRegression()
lg.fit(x_poly, y) 

plt.scatter(x, y, color="r")
plt.title("Linear regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(x, lg.predict(poly.fit_transform(x)), color="k")
